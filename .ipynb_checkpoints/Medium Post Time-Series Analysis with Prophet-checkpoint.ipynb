# %%
import matplotlib.pyplot as plt  # plots
import numpy as np  # vectors and matrices
import pandas as pd  # tables and data manipulations
import seaborn as sns  # more plotsA

sns.set()

import warnings  
from itertools import product  # some useful functions

import scipy.stats as scs
import statsmodels.api as sm
import statsmodels.formula.api as smf  # statistics and econometrics
import statsmodels.tsa.api as smt
from dateutil.relativedelta import \
    relativedelta  # working with dates with style
from scipy.optimize import minimize  # for function minimization
from tqdm.notebook import tqdm

warnings.filterwarnings("ignore") # `do not disturbe` mode

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import os
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy import stats

import matplotlib.pyplot as plt

# %%
import logging

from prophet import Prophet

logging.getLogger().setLevel(logging.ERROR)

# %%
df = daily_df.reset_index()
df.columns = ["ds", "y"]
df["ds"] = df["ds"].dt.tz_convert(None)
df.tail(n=3)
# Out:
#              ds    y
# 1773 2017-06-23  421
# 1774 2017-06-24  277
# 1775 2017-06-25  253

# %%
prediction_size = 30
train_df = df[:-prediction_size]
train_df.tail(n=3)
# Out:
#              ds    y
# 1743 2017-05-24  375
# 1744 2017-05-25  298
# 1745 2017-05-26  269

# %%
m = Prophet()
m.fit(train_df);
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:finish chain 1

# %%
future = m.make_future_dataframe(periods=prediction_size)
future.tail(n=3)
# Out:
#              ds
# 1773 2017-06-23
# 1774 2017-06-24
# 1775 2017-06-25

# %%
DATA_PATH = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/"

# %% [markdown]
# Adding another ML wiki dataset to view interesting patterns

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
df = pd.read_csv(DATA_PATH + "wiki_machine_learning.csv", sep=" ")
df = df[df["count"] != 0]
df.head()
# Out:
#           date  count lang              page  rank   month             title
# 81  2015-01-01   1414   en  Machine_learning  8708  201501  Machine_learning
# 80  2015-01-02   1920   en  Machine_learning  8708  201501  Machine_learning
# 79  2015-01-03   1338   en  Machine_learning  8708  201501  Machine_learning
# 78  2015-01-04   1404   en  Machine_learning  8708  201501  Machine_learning
# 77  2015-01-05   2264   en  Machine_learning  8708  201501  Machine_learning

# %%
df.date = pd.to_datetime(df.date)

# %%
plotly_df(df.set_index("date")[["count"]])
# Out:
# <div>                            <div id="34856e46-19eb-420d-a873-e7b21cc97d5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34856e46-19eb-420d-a873-e7b21cc97d5f")) {                    Plotly.newPlot(                        "34856e46-19eb-420d-a873-e7b21cc97d5f",                        [{"mode":"lines","name":"count","x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00:00","2015-05-31T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-06T00:00:00"," ...

# %% [markdown]
# Data seems quite noisy, almost constant with a few outliers

# %%
from prophet import Prophet

predictions = 30
#assign the size of the comparison dataset
df = df[["date", "count"]]
df.columns = ["ds", "y"]
df.tail()
# Out:
#             ds     y
# 382 2016-01-16  1644
# 381 2016-01-17  1836
# 376 2016-01-18  2983
# 375 2016-01-19  3389
# 372 2016-01-20  3559

# %% [markdown]
# Need to create the training dataframe, which we will do by taking all datapoints aside from the last 30, which will serve as a frame of reference

# %%
train_df = df[:-predictions].copy()
#creating training dataframe

# %%
m = Prophet()
m.fit(train_df);
#initializing prophet object and fitting it
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:finish chain 1

# %%
future = m.make_future_dataframe(periods=predictions)
future.tail(n=3)
#create 30 forecasts
# Out:
#             ds
# 380 2016-01-18
# 381 2016-01-19
# 382 2016-01-20

# %%
forecast = m.predict(future)
forecast.tail()
#save predictions in a dataframe
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 378 2016-01-16  2974.809126  1725.902039  2518.691112  2954.263991
# 379 2016-01-17  2980.146716  1843.026377  2662.235489  2958.768391
# 380 2016-01-18  2985.484306  2864.924375  3648.038072  2962.625195
# 381 2016-01-19  2990.821895  3120.043316  3963.930585  2966.827918
# 382 2016-01-20  2996.159485  3039.744637  3857.824077  2970.568349
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 378  2993.268922     -861.974711           -861.974711           -861.974711
# 379  3000.088553     -720.945291           -720.945291           -720.945291
# 380  3006.926341      281.432297            281.432297            281.432297
# 381  3013.349580      541.623035            541.623035            541.623035
# 382  3020.003294      425.717294            425.717294            425.717294
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 378 -861.974711   -861.974711   -861.974711                   0.0
# 379 -720.945291   -720.945291   -720.945291                   0.0
# 380  281.432297    281.432297    281.432297                   0.0
# 381  541.623035    541.623035    541.623035                   0.0
# 382  425.717294    425.717294    425.717294                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 378                         0.0                         0.0  2112.834415
# 379                         0.0                         0.0  2259.201424
# 380                         0.0                         0.0  3266.916602
# 381                         0.0                         0.0  3532.444930
# 382                         0.0                         0.0  3421.876780

# %%
m.plot(forecast)
#quite noisy

# %%
m.plot_components(forecast)
#easier to view analysis of components (by week, day, etc)

# %% [markdown]
# Seems to be less mentions over weekends, which makes sense, considering this is when people are spending time on non-coding activities

# %%
cmp_df = forecast.set_index("ds")[["yhat", "yhat_lower", "yhat_upper"]].join(
    df.set_index("ds")
)
#comparison dataframe which has actual values

# %%
cmp_df["e"] = cmp_df["y"] - cmp_df["yhat"]
cmp_df["p"] = 100 * cmp_df["e"] / cmp_df["y"]
print("MAPE = ", round(np.mean(abs(cmp_df[-predictions:]["p"])), 2))
print("MAE = ", round(np.mean(abs(cmp_df[-predictions:]["e"])), 2))
#creating our metrics, MAPE = mean absolute percentage error, MAE = mean absolute error
# Out:
# MAPE =  34.34
# MAE =  596.38

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats

plt.rcParams["figure.figsize"] = (15, 10)

# %% [markdown]
# Apply Dickey-Fuller test to see if data is stationary or not

# %%
sm.tsa.seasonal_decompose(train_df["y"].values, period=7).plot()
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(train_df["y"])[1])
#Dickey-Fuller test tell us if data is stationary or not
# Out:
# Dickey-Fuller test: p=0.107392

# %% [markdown]
# When decomposing by another factor, such as season, however, our data seems to be stationary

# %%
train_df.set_index("ds", inplace=True)
train_df["y_diff"] = train_df.y - train_df.y.shift(7)
sm.tsa.seasonal_decompose(train_df.y_diff[7:].values, period=7).plot()
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(train_df.y_diff[8:])[1])
#however, if we decompose by season, our data seems to be stationary
# Out:
# Dickey-Fuller test: p=0.000000

# %%
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(train_df.y_diff[13:].values.squeeze(), lags=48, ax=ax)

ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(train_df.y_diff[13:].values.squeeze(), lags=48, ax=ax)
#Auto-correlation plots tell us what our initial values for ARIMA are

# %% [markdown]
# Let us apply an autoregressive integrated moving average on this dataset

# %% [markdown]
# Added 5 tunable parameters/components (Order, seasonality, order of autoregression, ACF plot, order of seasonal integration)

# %%
ps = range(0, 2)
ds = range(0, 2)
qs = range(0, 4)
Ps = range(0, 4)
Ds = range(0, 3)
Qs = range(0, 2)

# %%
from itertools import product

parameters = product(ps, ds, qs, Ps, Ds, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 384

# %%
# %%time
import warnings

from tqdm.notebook import tqdm

results1 = []
best_aic = float("inf")
warnings.filterwarnings("ignore")

for param in tqdm(parameters_list):
    # try except is necessary, because on some sets of parameters the model can not be trained
    try:
        model = sm.tsa.statespace.SARIMAX(
            train_df["y"],
            order=(param[0], param[1], param[2]),
            seasonal_order=(param[3], param[4], param[5], 7),
            # train the model as is even if that would lead to a non-stationary / non-invertible model
            # see https://github.com/statsmodels/statsmodels/issues/6225 for details
        ).fit(disp=-1)

    except (ValueError, np.linalg.LinAlgError):
        continue

    aic = model.aic
    # save the best model, aic, parameters
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results1.append([param, model.aic])
#Tune hyperparameters, takes a while depending on computer machinery
# Out:
#   0%|          | 0/384 [00:00<?, ?it/s]
# CPU times: user 9min 37s, sys: 21min 48s, total: 31min 25s
# Wall time: 5min 25s

# %%
result_table1 = pd.DataFrame(results1)
result_table1.columns = ["parameters", "aic"]
print(result_table1.sort_values(by="aic", ascending=True).head())
# Out:
#              parameters          aic
# 42   (0, 0, 1, 3, 0, 0)    10.000000
# 61   (0, 0, 2, 2, 0, 1)    12.000000
# 280  (1, 0, 3, 3, 0, 0)    16.000000
# 376  (1, 1, 3, 3, 0, 1)   210.366354
# 165  (0, 1, 2, 3, 2, 1)  4961.632628

# %%
result_table1[
    result_table1["parameters"].isin(
        [(1, 0, 2, 3, 1, 0), (1, 1, 2, 3, 2, 1), (1, 1, 2, 3, 1, 1), (1, 0, 2, 3, 0, 0)]
    )
].sort_values(by="aic")
# Out:
#              parameters          aic
# 356  (1, 1, 2, 3, 2, 1)  4989.003294
# 354  (1, 1, 2, 3, 1, 1)  5019.555903
# 258  (1, 0, 2, 3, 1, 0)  5022.312524
# 256  (1, 0, 2, 3, 0, 0)  5183.820172

# %% [markdown]
# To further improve our model, we will apply a Box-Cox transformation

# %%
import scipy.stats

train_df["y_box"], lmbda = scipy.stats.boxcox(train_df["y"])
print("The optimal Box-Cox transformation parameter: %f" % lmbda)
#Apply boxcox transformation to improve performance
# Out:
# The optimal Box-Cox transformation parameter: 0.732841

# %%
results2 = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    # try except is necessary, because on some sets of parameters the model can not be trained
    try:
        model = sm.tsa.statespace.SARIMAX(
            train_df["y_box"],
            order=(param[0], param[1], param[2]),
            seasonal_order=(param[3], param[4], param[5], 7),
            # train the model as is even if that would lead to a non-stationary / non-invertible model
            # see https://github.com/statsmodels/statsmodels/issues/6225 for details
            enforce_stationary=False,  
            enforce_invertibility=False  
        ).fit(disp=-1)

    except (ValueError, np.linalg.LinAlgError):
        continue

    aic = model.aic
    # save the best model, aic, parameters
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results2.append([param, model.aic])

warnings.filterwarnings("default")
# Out:
#   0%|          | 0/384 [00:00<?, ?it/s]

# %%
result_table2 = pd.DataFrame(results2)
result_table2.columns = ["parameters", "aic"]
print(result_table2.sort_values(by="aic", ascending=True).head())
# Out:
#              parameters          aic
# 42   (0, 0, 1, 3, 0, 0)    10.000000
# 376  (1, 1, 3, 3, 0, 0)    63.929950
# 261  (1, 0, 2, 3, 2, 1)  3528.443819
# 285  (1, 0, 3, 3, 2, 1)  3529.820329
# 213  (1, 0, 0, 3, 2, 1)  3530.231534

# %%
result_table2[
    result_table2["parameters"].isin(
        [(1, 0, 2, 3, 1, 0), (1, 1, 2, 3, 2, 1), (1, 1, 2, 3, 1, 1), (1, 0, 2, 3, 0, 0)]
    )
].sort_values(by="aic")
# Out:
#              parameters          aic
# 258  (1, 0, 2, 3, 1, 0)  3556.880030
# 357  (1, 1, 2, 3, 2, 1)  3558.277490
# 355  (1, 1, 2, 3, 1, 1)  3558.624194
# 256  (1, 0, 2, 3, 0, 0)  3677.479007

# %%
best_model = sm.tsa.statespace.SARIMAX(
    train_df["y_box"],
    order=(1, 0, 2),
    seasonal_order=(3, 2, 1, 7),
    enforce_stationary=False,  
    enforce_invertibility=False  
).fit(disp=-1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
print(best_model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               y_box   No. Observations:                  353
# Model:             SARIMAX(1, 0, 2)x(3, 2, [1], 7)   Log Likelihood               -1756.222
# Date:                             Mon, 31 Oct 2022   AIC                           3528.444
# Time:                                     00:11:31   BIC                           3559.052
# Sample:                                          0   HQIC                          3540.641
#                                              - 353
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8077      0.125      6.477      0.000       0.563       1.052
# ma.L1         -0.3196      0.131     -2.449      0.014      -0.575      -0.064
# ma.L2         -0.1959      0.096     -2.051      0.040      -0.383      -0.009
# ar.S.L7       -0.6536      0.040    -16.414      0.000      -0.732      -0.576
# ar.S.L14      -0.4411      0.058     -7.562      0.000      -0.555      -0.327
# ar.S.L21      -0.2716      0.043     -6.348      0.000      -0.355      -0.188
# ma.S.L7       -1.0394      0.052    -19.966      0.000      -1.141      -0.937
# sigma2      1547.5365    122.065     12.678      0.000    1308.294    1786.778
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):               541.82
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                             0.96
# Prob(H) (two-sided):                  0.10   Kurtosis:                         8.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ACF and Dickey-Fuller test to measure how stationary data is

# %%
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u"Residuals")

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Student's test: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Student's test: p=0.122152
# Dickey-Fuller test: p=0.000000

# %%
def invboxcox(y, lmbda):
    # reverse Box Cox transformation so we can graph our final predictions
    if lmbda == 0:
        return np.exp(y)
    else:
        return np.exp(np.log(lmbda * y + 1) / lmbda)

# %%
train_df["arima_model"] = invboxcox(best_model.fittedvalues, lmbda)

train_df.y.tail(200).plot()
train_df.arima_model[13:].tail(200).plot(color="r")
plt.ylabel("wiki pageviews");

# %% [markdown]
# Our model performed quite well but was computationally intensive
